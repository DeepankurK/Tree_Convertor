# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/home/deepank/Downloads/Prof_Hamim/Convertor_project/Code/result_p_to_c.txt',header=None)

# %%
df 
# This contains data for 10 datasets as rows and 6 algorithms and 3 clustering comparing metrics (6*3) as columns.
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.464040  0.928584  0.935660  1.086263  0.944242  0.949081  1.086263
# 1  2.910303  0.729349  0.842735  2.910303  0.729349  0.842735  2.910303
# 2  2.371919  0.694364  0.641074  2.371919  0.694364  0.641074  2.371919
# 3  1.153535  0.735798  0.654518  3.092323  0.646833  0.784603  3.092323
# 4  0.000000  0.000000  0.000000  2.202222  0.762453  0.723747  2.202222
# 5  2.479798  0.840283  0.840174  1.565051  0.854180  0.855084  1.525455
# 6  1.616970  0.842486  0.738173  1.186465  0.863849  0.761882  1.186465
# 7  0.000000  0.000000  0.000000  2.671515  0.678668  0.693095  2.646465
# 8  1.055556  0.823225  0.918633  2.156566  0.641601  0.835870  2.156566
# 9  0.000000  0.000000  0.000000  3.440606  0.570613  0.549684  3.440606
#
#          7         8         9         10        11        12        13  \
# 0  0.944242  0.949081  1.086263  0.944242  0.949081  1.605657  0.877791
# ...

# %%
df.replace(0,np.nan).boxplot(figsize=(30,30)) 
# Column 0,3,6,9,12,15 are normalized pairwise distance for 6 algorithms used.
# Column 1,4,7,10,13,16 are V-Measure for 6 algorithms used.
# Column 2,5,8,11,14,17 are Fowlkes Mallows Score for 6 algorithms used.
# The six algorithms are in a sequential order (as used):-
#1. Affinity Propagation
#2. Agglomerative Clustering
#3. Birch
#4. KMeans
#5. KMedoids
#6. SpectralClustering

# %%
df2=pd.read_csv('/home/deepank/Downloads/Prof_Hamim/Convertor_project/Code/result_m_to_c.txt',header=None)

# %%
df 
# This contains data for 10 datasets as rows and 6 algorithms and 3 clustering comparing metrics (6*3) as columns.
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.464040  0.928584  0.935660  1.086263  0.944242  0.949081  1.086263
# 1  2.910303  0.729349  0.842735  2.910303  0.729349  0.842735  2.910303
# 2  2.371919  0.694364  0.641074  2.371919  0.694364  0.641074  2.371919
# 3  1.153535  0.735798  0.654518  3.092323  0.646833  0.784603  3.092323
# 4  0.000000  0.000000  0.000000  2.202222  0.762453  0.723747  2.202222
# 5  2.479798  0.840283  0.840174  1.565051  0.854180  0.855084  1.525455
# 6  1.616970  0.842486  0.738173  1.186465  0.863849  0.761882  1.186465
# 7  0.000000  0.000000  0.000000  2.671515  0.678668  0.693095  2.646465
# 8  1.055556  0.823225  0.918633  2.156566  0.641601  0.835870  2.156566
# 9  0.000000  0.000000  0.000000  3.440606  0.570613  0.549684  3.440606
#
#          7         8         9         10        11        12        13  \
# 0  0.944242  0.949081  1.086263  0.944242  0.949081  1.605657  0.877791
# ...

# %%
df.replace(0,np.nan).boxplot(figsize=(30,30)) 
# Column 0,3,6,9,12,15 are normalized pairwise distance for 6 algorithms used.
# Column 1,4,7,10,13,16 are V-Measure for 6 algorithms used.
# Column 2,5,8,11,14,17 are Fowlkes Mallows Score for 6 algorithms used.
# The six algorithms are in a sequential order (as used):-
#1. Affinity Propagation
#2. Agglomerative Clustering
#3. Birch
#4. KMeans
#5. KMedoids
#6. SpectralClustering
